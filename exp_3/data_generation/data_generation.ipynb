# %%
from helper_functions_data_gen import create_synthetic_data

# %%
size = "small"
model_name = "gemma" 
from_line = 0


models = {
    "small": {
        "llama": "llama-3.1-8b-instant", 
        "gemma": "gemma2-9b-it"
        },
    "medium": {
        "llama": "meta-llama/Meta-Llama-3.1-70B-Instruct",
        "qwen": "Qwen/Qwen2.5-72B-Instruct",
        "mistral": "mistral-large-latest", 
        "command": "command-r-plus"
        },
    "large":{
        "llama": "meta-llama/Meta-Llama-3.1-405B-Instruct",
        "deepseek": "deepseek-ai/DeepSeek-V3",
        "gpt": "gpt-4o",
        "gemini": "gemini-2.0-flash"
        }
}

model = models[size][model_name]


input_path = f"/Users/maxschaffelder/Desktop/Thesis/data/exp_3/cnn_dailymail_sampled_100.jsonl"

output_path = f"/Users/maxschaffelder/Desktop/Thesis/data/exp_3/generated/{size}/summaries_{model_name}.jsonl" 


create_synthetic_data(model, input_path, output_path, split=[from_line, None])
# Out:
# Done generating data.
